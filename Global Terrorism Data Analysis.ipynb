# %%
# Data Visulization...........................

#import of necessary modules..................

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True)

# %%
#import warnings to ignore the warnings in the set loading.........

import warnings
warnings.filterwarnings("ignore")

# %%
#load the global terrorism data set........
terrorism =pd.read_csv("C:/Users/anilk/Python Jupyter NoteBook/globalterrorism.csv",encoding='ISO-8859-1')

#show top column details...
terrorism .head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  1.970000e+11   1970       7     2        NaN         0        NaN       58
# 1  1.970000e+11   1970       0     0        NaN         0        NaN      130
# 2  1.970010e+11   1970       1     0        NaN         0        NaN      160
# 3  1.970010e+11   1970       1     0        NaN         0        NaN       78
# 4  1.970010e+11   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
#display the shape of the dataset..

terrorism .shape
# Out:
# (181691, 135)

# %%
#display the list of columns in data set..

terrorism .columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
terrorism .columns.nunique()   #count of total no of columns....
# Out:
# 135

# %%
#taking some of the important columns that are used in data analysis........

selected_columns=['iyear','imonth','iday','country_txt','region_txt','provstate','city','latitude','longitude','attacktype1_txt','targtype1_txt','weaptype1_txt','nkill','nwound','gname']
terrorism  = terrorism [selected_columns]

# %%
terrorism
# Out:
#         iyear  imonth  iday         country_txt                   region_txt  \
# 0        1970       7     2  Dominican Republic  Central America & Caribbean
# 1        1970       0     0              Mexico                North America
# 2        1970       1     0         Philippines               Southeast Asia
# 3        1970       1     0              Greece               Western Europe
# 4        1970       1     0               Japan                    East Asia
# ...       ...     ...   ...                 ...                          ...
# 181686   2017      12    31             Somalia           Sub-Saharan Africa
# 181687   2017      12    31               Syria   Middle East & North Africa
# 181688   2017      12    31         Philippines               Southeast Asia
# 181689   2017      12    31               India                   South Asia
# 181690   2017      12    31         Philippines               Southeast Asia
#
# ...

# %%
terrorism .columns
# Out:
# Index(['iyear', 'imonth', 'iday', 'country_txt', 'region_txt', 'provstate',
#        'city', 'latitude', 'longitude', 'attacktype1_txt', 'targtype1_txt',
#        'weaptype1_txt', 'nkill', 'nwound', 'gname'],
#       dtype='object')

# %%
#Renaming columns for better understanding...............

terrorism =terrorism .rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','region_txt':'Region','provstate':'ProvinceState','city':'City','latitude':'Latitude','longitude':'Longitude','attacktype1_txt':'AttackType','targtype1_txt':'TargetType','weaptype1_txt':'WeaponType','nkill':'No_Kills','nwound':'No_Wounded','gname':'Gang_Name'})

# %%
terrorism
# Out:
#         Year  Month  Day             Country                       Region  \
# 0       1970      7    2  Dominican Republic  Central America & Caribbean
# 1       1970      0    0              Mexico                North America
# 2       1970      1    0         Philippines               Southeast Asia
# 3       1970      1    0              Greece               Western Europe
# 4       1970      1    0               Japan                    East Asia
# ...      ...    ...  ...                 ...                          ...
# 181686  2017     12   31             Somalia           Sub-Saharan Africa
# 181687  2017     12   31               Syria   Middle East & North Africa
# 181688  2017     12   31         Philippines               Southeast Asia
# 181689  2017     12   31               India                   South Asia
# 181690  2017     12   31         Philippines               Southeast Asia
#
#           ProvinceState           City   Latitude   Longitude  \
# ...

# %%
terrorism .describe()
# Out:
#                 Year          Month            Day       Latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean     2002.638997       6.467277      15.505650      23.498343
# std        13.259430       3.388303       8.814043      18.569242
# min      1970.000000       0.000000       0.000000     -53.154613
# 25%      1991.000000       4.000000       8.000000      11.510046
# 50%      2009.000000       6.000000      15.000000      31.467463
# 75%      2014.000000       9.000000      23.000000      34.685087
# max      2017.000000      12.000000      31.000000      74.633553
#
#           Longitude       No_Kills     No_Wounded
# count  1.771340e+05  171378.000000  165380.000000
# mean  -4.586957e+02       2.403272       3.167668
# std    2.047790e+05      11.545741      35.949392
# min   -8.618590e+07       0.000000       0.000000
# 25%    4.545640e+00       0.000000       0.000000
# 50%    4.324651e+01       0.000000       0.000000
# ...

# %%
terrorism .dtypes
# Out:
# Year               int64
# Month              int64
# Day                int64
# Country           object
# Region            object
# ProvinceState     object
# City              object
# Latitude         float64
# Longitude        float64
# AttackType        object
# TargetType        object
# WeaponType        object
# No_Kills         float64
# No_Wounded       float64
# Gang_Name         object
# dtype: object

# %%
#performing data cleaning and handling missing values.............

terrorism .info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Year           181691 non-null  int64
#  1   Month          181691 non-null  int64
#  2   Day            181691 non-null  int64
#  3   Country        181691 non-null  object
#  4   Region         181691 non-null  object
#  5   ProvinceState  181270 non-null  object
#  6   City           181256 non-null  object
#  7   Latitude       177135 non-null  float64
#  8   Longitude      177134 non-null  float64
#  9   AttackType     181691 non-null  object
#  10  TargetType     181691 non-null  object
#  11  WeaponType     181691 non-null  object
#  12  No_Kills       171378 non-null  float64
#  13  No_Wounded     165380 non-null  float64
#  14  Gang_Name      181691 non-null  object
# dtypes: float64(4), int64(3), object(8)
# memory usage: 20.8+ MB

# %%
terrorism .isnull().sum()
# Out:
# Year                 0
# Month                0
# Day                  0
# Country              0
# Region               0
# ProvinceState      421
# City               435
# Latitude          4556
# Longitude         4557
# AttackType           0
# TargetType           0
# WeaponType           0
# No_Kills         10313
# No_Wounded       16311
# Gang_Name            0
# dtype: int64

# %%
terrorism ['ProvinceState']=terrorism ['ProvinceState'].fillna('UnKnown')
terrorism ['City']=terrorism ['City'].fillna('UnKnown')
terrorism ['Latitude']=terrorism ['Latitude'].fillna(0)
terrorism ['Longitude']=terrorism ['Longitude'].fillna(0)
terrorism ['No_Kills']=terrorism ['No_Kills'].fillna(0)
terrorism ['No_Wounded']=terrorism ['No_Wounded'].fillna(0)

# %%
#display of region with total of kills................
group=terrorism .groupby(['Region']).agg({'No_Kills':'sum'})
group.sort_values(by=['No_Kills'],ascending=True,inplace=True)
print(group)
# Out:
#                              No_Kills
# Region
# Australasia & Oceania           150.0
# Central Asia                   1000.0
# East Asia                      1152.0
# North America                  4916.0
# Western Europe                 6694.0
# Eastern Europe                 7415.0
# Southeast Asia                15637.0
# Central America & Caribbean   28708.0
# South America                 28849.0
# Sub-Saharan Africa            78386.0
# South Asia                   101319.0
# Middle East & North Africa   137642.0

# %%
#top affected regions with location cordinates........

terrorism ['Region'].value_counts().head(5)
# Out:
# Region
# Middle East & North Africa    50474
# South Asia                    44974
# South America                 18978
# Sub-Saharan Africa            17550
# Western Europe                16639
# Name: count, dtype: int64

# %%
terrorism ['Country'].value_counts().head(5)
# Out:
# Country
# Iraq           24636
# Pakistan       14368
# Afghanistan    12731
# India          11960
# Colombia        8306
# Name: count, dtype: int64

# %%
terrorism ['City'].value_counts().head(5)
# Out:
# City
# Unknown    9775
# Baghdad    7589
# Karachi    2652
# Lima       2359
# Mosul      2265
# Name: count, dtype: int64

# %%
terrorism ['ProvinceState'].value_counts().head(5)
# Out:
# ProvinceState
# Baghdad             7645
# Northern Ireland    4498
# Unknown             4290
# Balochistan         3710
# Saladin             3411
# Name: count, dtype: int64

# %%
terrorism ['TargetType'].value_counts().head(10)
# Out:
# TargetType
# Private Citizens & Property       43511
# Military                          27984
# Police                            24506
# Government (General)              21283
# Business                          20669
# Transportation                     6799
# Utilities                          6023
# Unknown                            5898
# Religious Figures/Institutions     4440
# Educational Institution            4322
# Name: count, dtype: int64

# %%
#list of most dangerous terrosim gangs

terrorism ['Gang_Name'].value_counts().head(10)
# Out:
# Gang_Name
# Unknown                                             82782
# Taliban                                              7478
# Islamic State of Iraq and the Levant (ISIL)          5613
# Shining Path (SL)                                    4555
# Farabundo Marti National Liberation Front (FMLN)     3351
# Al-Shabaab                                           3288
# New People's Army (NPA)                              2772
# Irish Republican Army (IRA)                          2671
# Revolutionary Armed Forces of Colombia (FARC)        2487
# Boko Haram                                           2418
# Name: count, dtype: int64

# %%
#list of weapons used in attack

print(terrorism ['WeaponType'].value_counts().head(10))
# Out:
# WeaponType
# Explosives                                                                     92426
# Firearms                                                                       58524
# Unknown                                                                        15157
# Incendiary                                                                     11135
# Melee                                                                           3655
# Chemical                                                                         321
# Sabotage Equipment                                                               141
# Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)      136
# Other                                                                            114
# Biological                                                                        35
# Name: count, dtype: int64

# %%
terrorism .describe(include='all')
# Out:
#                  Year          Month            Day Country  \
# count   181691.000000  181691.000000  181691.000000  181691
# unique            NaN            NaN            NaN     205
# top               NaN            NaN            NaN    Iraq
# freq              NaN            NaN            NaN   24636
# mean      2002.638997       6.467277      15.505650     NaN
# std         13.259430       3.388303       8.814043     NaN
# min       1970.000000       0.000000       0.000000     NaN
# 25%       1991.000000       4.000000       8.000000     NaN
# 50%       2009.000000       6.000000      15.000000     NaN
# 75%       2014.000000       9.000000      23.000000     NaN
# max       2017.000000      12.000000      31.000000     NaN
#
#                             Region ProvinceState     City       Latitude  \
# count                       181691        181691   181691  181691.000000
# unique                          12          2856    36674            NaN
# ...

# %%
#DATA VISULAIZATION USING VARIOUS PLOT METHODS>>>>>>>>>>>>>>>>>>>>>>>
plt.figure(figsize=(20,10))

titles = ['Attacks on Day','Attacks On Month'] 
columns=['Day','Month'] 
for i,col in enumerate(columns): 
    plt.subplot(2,1,i+1) 
    plt.title(titles[i]) 
    sns.countplot(x=terrorism [col])

plt.tight_layout() 
plt.show()

# %%
#Number of incidents/Terrorist Attacks per year

incidents_per_year=terrorism ['Year'].value_counts().sort_index()
plt.figure(figsize=(10,6))
plt.bar(incidents_per_year.index,incidents_per_year.values)
plt.xlabel('Year')
plt.ylabel('Number Of Incidents')
plt.title('Number of Terrorist Attacks Per Year')
plt.show()

# %%
#Different Types Of Terrorist Attacks....................

attack=terrorism ['AttackType'].value_counts()

plt.figure(figsize=(8,8))
plt.pie(attack,labels=attack.index,explode=(0,0,0,0,0,0,0.1,0.3,0),autopct='%1.1f%%',startangle=140)
plt.title=('Distribution of Attacks')
plt.show()

# %%
#Attacks by region..............

terrorism .groupby(['Region','AttackType']).size().unstack().plot(kind='box',stacked=True)
plt.xlabel('Region')
plt.ylabel('Number Of Attacks')
plt.xticks(rotation=45,ha='right')
plt.show()

# %%
#correlation matrix................

correlation=terrorism.select_dtypes(include=[np.number]).corr()
plt.figure(figsize=(10,6))
sns.heatmap(correlation,annot=True,cmap='coolwarm')
plt.show()
